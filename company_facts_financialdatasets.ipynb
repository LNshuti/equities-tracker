# %% [markdown]
# <a href="https://colab.research.google.com/github/LNshuti/equities-tracker/blob/main/company_facts_financialdatasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hi there 👋 - [financialdatasets.ai](https://www.financialdatasets.ai) is a stock market API that provides:
#
# *   income statements
# *   balance sheets
# *   cash flow statements
# *   sec filings
# *   stock prices
#
# This is a quick start guide on how to get **facts** about a company via the API.
#
# The company/facts endpoint is completely free to use.
#
# **Questions?**
#
# The full API documentation is available [here](https://docs.financialdatasets.ai/api-reference/endpoint/company/facts).
#
# You can also DM me on [twitter](https://www.x.com/virattt).

# %%
import requests

ticker = 'AAPL'

url = (
    f'https://api.financialdatasets.ai/company/facts'
    f'?ticker={ticker}'
)

response = requests.get(url)

# %%
# Pretty print the response JSON
import json
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "company_facts": {
#     "ticker": "AAPL",
#     "name": "Apple Inc.",
#     "cik": "0000320193",
#     "market_cap": 3354032622200.0,
#     "number_of_employees": 161000,
#     "sic_code": "3571",
#     "sic_description": "Electronic Computers",
#     "website_url": "https://www.apple.com",
#     "listing_date": "1980-12-12",
#     "is_active": true
#   }
# }

# %% [markdown]
# # 2. GET facts for multiple tickers

# %%
tickers = ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'META', 'BRK.B', 'TSLA', 'AMZN', 'UBER', 'FDX', 'UPS', 'WMT', 'EBAY', 'TGT', 'EXPD', 'CHRW', 'XPO', 'R', 'JBHT', 'ODFL', 'KNX', 'CSX', 'UNP', 'NSC', 'AZO', 'AAP', 'ORLY', 'GPC', 'KMX', 'LKQ', 'PAG']


facts = []

for ticker in tickers:
    url = (
        f'https://api.financialdatasets.ai/company/facts'
        f'?ticker={ticker}'
    )
    response = requests.get(url)
    facts.append(response.json())

# %%
import pandas as pd
from IPython.display import display, HTML

# Extract the company_facts from each item in the list
company_facts_list = [item['company_facts'] for item in facts]

# Create a DataFrame
df = pd.DataFrame(company_facts_list)

# Rename columns to be more readable
df = df.rename(columns={
    'ticker': 'Ticker',
    'name': 'Company Name',
    'cik': 'CIK',
    'market_cap': 'Market Cap ($)',
    'number_of_employees': 'Employees',
    'sic_code': 'SIC Code',
    'sic_description': 'SIC Description',
    'website_url': 'Website',
    'listing_date': 'Listing Date',
    'is_active': 'Active'
})

# Format market cap as billions with 2 decimal places
df['Market Cap ($)'] = df['Market Cap ($)'].apply(lambda x: f"{x/1e9:.2f}B")

# Define CSS styles
styles = [
    dict(selector="th", props=[("background-color", "#2383F4"),
                               ("color", "white"),
                               ("font-weight", "bold"),
                               ("padding", "8px")]),
    dict(selector="td", props=[("padding", "10px 15px")]),
    dict(selector="", props=[("border-collapse", "collapse"),
                             ("font-family", "Arial, sans-serif")])
]

# Format the DataFrame
styled_df = df.style.set_properties(**{
    'background-color': '#f0f0f0',
    'color': 'black',
    'border-color': 'white'
}).set_table_styles(styles).format({
    'Employees': '{:,}',
    'Listing Date': lambda x: pd.to_datetime(x).strftime('%Y-%m-%d')
}).hide(axis="index")

# Display the styled DataFrame
display(HTML(styled_df.to_html(index=False)))
# Out:
# <style type="text/css">
# #T_b7a12 th {
#   background-color: #2383F4;
#   color: white;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_b7a12 td {
#   padding: 10px 15px;
# }
# #T_b7a12  {
#   border-collapse: collapse;
#   font-family: Arial, sans-serif;
# }
#T_b7a12_row12_col2, #T_b7a12_row12_col3, #T_b7a12_row12_col4, #T_b7a12_row12_col5, #T_b7a12_row12_col6, #T_b7a12_row12_col7, #T_b7a12_row12_col8, #T_b7a12_row12_col9, #T_b7a12_row13_col0, #T_b7a12_row13_col1, #T_b7a12_row13_col2, #T_b7a12_row13_col3, #T_b7a12_row13_col4, #T_b7a12_row13_col5, #T_b7a12_row13_col6, #T_b7a12_row13_col7, #T_b7a12_row13_col8, #T_b7a12_row13_col9, #T_b7a12_row14_col0, #T_b7a12_row14_col1, #T_b7a12_row14_col2, #T_b7a12_row14_col3, #T_b7a12_row14_col4, #T_b7a12_row14_col5, #T_b7a12_row14_col6, #T_b7a12_row14_col7, #T_b7a12_row14_col8, #T_b7a12_row14_col9, #T_b7a12_row15_col0, #T_b7a12_row15_col1, #T_b7a12_row15_col2, #T_b7a12_row15_col3, #T_b7a12_row15_col4, #T_b7a12_row15_col5, #T_b7a12_row15_col6, #T_b7a12_row15_col7, #T_b7a12_row15_col8, #T_b7a12_row15_col9, #T_b7a12_row16_col0, #T_b7a12_row16_col1, #T_b7a12_row16_col2, #T_b7a12_row16_col3, #T_b7a12_row16_col4, #T_b7a12_row16_col5, #T_b7a12_row16_col6, #T_b7a12_row16_col7, #T_b7a12_row16_col8, #T_b7a12_row16_col9, #T_b7a12_row17_col0, #T_b7a12_row17_col1, #T_b7a12_row17_col2, #T_b7a12_row17_col3, #T_b7a12_row17_col4, #T_b7a12_row17_col5, #T_b7a12_row17_col6, #T_b7a12_row17_col7, #T_b7a12_row17_col8, #T_b7a12_row17_col9, #T_b7a12_row18_col0, #T_b7a12_row18_col1, #T_b7a12_row18_col2, #T_b7a12_row18_col3, #T_b7a12_row18_col4, #T_b7a12_row18_col5, #T_b7a12_row18_col6, #T_b7a12_row18_col7, #T_b7a12_row18_col8, #T_b7a12_row18_col9, #T_b7a12_row19_col0, #T_b7a12_row19_col1, #T_b7a12_row19_col2, #T_b7a12_row19_col3, #T_b7a12_row19_col4, #T_b7 ...
#   background-color: #f0f0f0;
#   color: black;
#   border-color: white;
# }
# </style>
# <table id="T_b7a12">
#   <thead>
#     <tr>
#       <th id="T_b7a12_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_b7a12_level0_col1" class="col_heading level0 col1" >Company Name</th>
#       <th id="T_b7a12_level0_col2" class="col_heading level0 col2" >CIK</th>
#       <th id="T_b7a12_level0_col3" class="col_heading level0 col3" >Market Cap ($)</th>
#       <th id="T_b7a12_level0_col4" class="col_heading level0 col4" >Employees</th>
#       <th id="T_b7a12_level0_col5" class="col_heading level0 col5" >SIC Code</th>
#       <th id="T_b7a12_level0_col6" class="col_heading level0 col6" >SIC Description</th>
#       <th id="T_b7a12_level0_col7" class="col_heading level0 col7" >Website</th>
#       <th id="T_b7a12_level0_col8" class="col_heading level0 col8" >Listing Date</th>
#       <th id="T_b7a12_level0_col9" class="col_heading level0 col9" >Active</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b7a12_row0_col0" class="data row0 col0" >AAPL</td>
#       <td id="T_b7a12_row0_col1" class="data row0 col1" >Apple Inc.</td>
#       <td id="T_b7a12_row0_col2" class="data row0 col2" >0000320193</td>
#       <td id="T_b7a12_row0_col3" class="data row0 col3" >3354.03B</td>
#       <td id="T_b7a12_row0_col4" class="data row0 col4" >161,000</td>
#       <
